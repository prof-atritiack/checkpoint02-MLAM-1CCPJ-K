# %% [markdown]
# # Checkpoint 02 — Modelagem Linear Para Aprendizado de Máquina
#
# **Turma:**
# **Integrantes:**
# - Nome completo 1
# - Nome completo 2
# - Nome completo 3
# - Nome completo 4
# - Nome completo 5
# - Nome completo 6
#
# **Apresentador(a):**

# %% [markdown]
# ## 1. Escolha e justificativa da base de dados
#
# **Nome da base de dados:**
# **Fonte:**
# **Link de acesso:**
#
# ---
#
# *Escreva aqui o texto de justificativa (mínimo 150 palavras). Explique por que esta base foi escolhida, qual é o contexto real dos dados, quem os coletou, para quê e quando, por que ela é adequada para os objetivos desta atividade e quais limitações ou ressalvas o grupo identifica.*

# %% [markdown]
# ## 2. Carregamento e inspeção inicial dos dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Carregue o dataset abaixo
# df = pd.read_csv('nome_do_arquivo.csv')

# Inspeção inicial
# df.shape
# df.head()
# df.dtypes
# df.info()
# df.describe()

# %% [markdown]
# ## 3. Classificação das variáveis
#
# Preencha a tabela abaixo com todas as colunas do dataset. A coluna de justificativa deve conter argumentação própria do grupo.
#
# | Coluna | Tipo | Subtipo | Justificativa |
# |--------|------|---------|---------------|
# | ...    | qualitativa / quantitativa | nominal / ordinal / discreta / contínua | ... |

# %% [markdown]
# ## 4. Tabelas de distribuição de frequências

# %% [markdown]
# ### 4.1 Variável qualitativa nominal
#
# **Variável escolhida:**
# **Justificativa da escolha:**

# %%
# Tabela de frequências — variável qualitativa nominal
# Inclua: frequência absoluta, frequência relativa e frequência acumulada

# coluna = 'nome_da_coluna'

# freq_abs = df[coluna].value_counts()
# freq_rel = df[coluna].value_counts(normalize=True)
# freq_acum = freq_rel.cumsum()

# tabela = pd.DataFrame({
#     'Frequência Absoluta': freq_abs,
#     'Frequência Relativa (%)': (freq_rel * 100).round(2),
#     'Frequência Acumulada (%)': (freq_acum * 100).round(2)
# })

# tabela

# %% [markdown]
# **Interpretação:**
# *Escreva aqui ao menos dois parágrafos interpretando o que os dados mostram. Extraia significado no contexto real do dataset — não apenas descreva os números.*

# %% [markdown]
# ### 4.2 Variável qualitativa ordinal
#
# **Variável escolhida:**
# **Justificativa da escolha:**

# %%
# Tabela de frequências — variável qualitativa ordinal
# Inclua: frequência absoluta, frequência relativa e frequência acumulada
# Atenção: para variáveis ordinais, a ordem das categorias importa — garanta que a tabela respeite essa ordem

# coluna = 'nome_da_coluna'
# ordem = ['categoria_1', 'categoria_2', 'categoria_3']  # defina a ordem correta

# freq_abs = df[coluna].value_counts().reindex(ordem)
# freq_rel = freq_abs / freq_abs.sum()
# freq_acum = freq_rel.cumsum()

# tabela = pd.DataFrame({
#     'Frequência Absoluta': freq_abs,
#     'Frequência Relativa (%)': (freq_rel * 100).round(2),
#     'Frequência Acumulada (%)': (freq_acum * 100).round(2)
# })

# tabela

# %% [markdown]
# **Interpretação:**
# *Escreva aqui ao menos dois parágrafos interpretando o que os dados mostram. Extraia significado no contexto real do dataset — não apenas descreva os números.*

# %% [markdown]
# ### 4.3 Variável quantitativa discreta
#
# **Variável escolhida:**
# **Justificativa da escolha:**

# %%
# Tabela de frequências — variável quantitativa discreta
# Inclua: frequência absoluta, frequência relativa e frequência acumulada

# coluna = 'nome_da_coluna'

# freq_abs = df[coluna].value_counts().sort_index()
# freq_rel = freq_abs / freq_abs.sum()
# freq_acum = freq_rel.cumsum()

# tabela = pd.DataFrame({
#     'Frequência Absoluta': freq_abs,
#     'Frequência Relativa (%)': (freq_rel * 100).round(2),
#     'Frequência Acumulada (%)': (freq_acum * 100).round(2)
# })

# tabela

# %% [markdown]
# **Interpretação:**
# *Escreva aqui ao menos dois parágrafos interpretando o que os dados mostram. Extraia significado no contexto real do dataset — não apenas descreva os números.*

# %% [markdown]
# ### 4.4 Variável quantitativa contínua
#
# **Variável escolhida:**
# **Justificativa da escolha:**
# **Regra utilizada para definição do número de classes:**
# **Número de classes definido:**
# **Justificativa:**

# %%
# Tabela de frequências — variável quantitativa contínua (por classes)
# O número de classes deve ser justificado pelo grupo (Sturges, Scott ou outra regra)

# coluna = 'nome_da_coluna'
# n = len(df[coluna].dropna())

# Regra de Sturges: k = 1 + 3.322 * log10(n)
# k = int(np.ceil(1 + 3.322 * np.log10(n)))

# classes = pd.cut(df[coluna], bins=k)
# freq_abs = classes.value_counts().sort_index()
# freq_rel = freq_abs / freq_abs.sum()
# freq_acum = freq_rel.cumsum()

# tabela = pd.DataFrame({
#     'Frequência Absoluta': freq_abs,
#     'Frequência Relativa (%)': (freq_rel * 100).round(2),
#     'Frequência Acumulada (%)': (freq_acum * 100).round(2)
# })

# tabela

# %% [markdown]
# **Interpretação:**
# *Escreva aqui ao menos dois parágrafos interpretando o que os dados mostram. Extraia significado no contexto real do dataset — não apenas descreva os números.*

# %% [markdown]
# ## 5. Conclusão
#
# *O que a distribuição dos dados revela sobre o problema real? O que o grupo aprendeu sobre os dados a partir desta análise? Havia algo inesperado? As distribuições encontradas fazem sentido dado o contexto da base escolhida?*
